# %% [markdown]
# <a href="https://colab.research.google.com/github/siherm/PUMA/blob/main/PUMA_Duplicate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install pydantic
# Out:
# Requirement already satisfied: pydantic in c:\users\jomar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\jomar\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic) (4.2.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\jomar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import dictdiffer
import os
from pprint import  pprint
from pyPUMA import PUMACollection, PUMAEntry

# %% [markdown]
# ## Configuration

# %%
# 1 - Fetch data from PUMA (Replace if necessary or add to environment vars)
username = "jo-hollenbeck"
token = "5efe8593931e3c325f9399812b1de5da"

# %% [markdown]
# ## Utilizing the PUMACollection
# ### Application: Find duplicates

# %%
# Fetch remote collection from Simtech group
collection = PUMACollection.from_web_api(username, token)

# Find all duplicates and sort into data structure
duplicates = collection.gather_duplicates("doi")

# %%
duplicate_dois = set([
    duplicate.doi
    for duplicate_set in duplicates.values()
    for duplicate in duplicate_set
])

# %%
unique_collection = [
    record
    for record in collection
    if record.doi not in duplicate_dois
]

unique_collection
# Out:
# [PUMAEntry(bibtex={'title': 'Glioblastoma, from disease understanding towards optimal cell-based in vitro models', 'bibtexKey': 'Boccellato2022', 'misc': '  issn = {2211-3436},\n  doi = {10.1007/s13402-022-00684-7}', 'entrytype': 'article', 'author': 'Boccellato, Chiara and Rehm, Markus', 'journal': 'Cellular Oncology', 'day': '28', 'month': 'jun', 'year': '2022', 'url': 'https://doi.org/10.1007/s13402-022-00684-7', 'intrahash': '056a5dc5d9f8aea47d25238d442d91b0', 'interhash': '0e493fecf72e6cc825c2aba862c3962c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/056a5dc5d9f8aea47d25238d442d91b0'}, title='Glioblastoma, from disease understanding towards optimal cell-based in vitro models', user='simtech', author='Boccellato, Chiara and Rehm, Markus', entrytype='article', tag=['2022', 'EXC2075', 'from:cristiano', 'izi', 'morrison', 'pn2', 'simtech'], journal='Cellular Oncology', preprint_id=None, url='https://doi.org/10.1007/s13402-022-00684-7', doi='10.1007/s13402-022-00684-7', isbn=None, issn='2211-3436', misc=None),
#  PUMAEntry(bibtex={'title': 'Flanking sequences influence the activity of TET1 and TET2 methylcytosine dioxygenases and affect genomic 5hmC patterns', 'bibtexKey': 'Adam2022', 'misc': '  issn = {2399-3642},\n  doi = {10.1038/s42003-022-03033-4}', 'bibtexAbstract': 'TET dioxygenases convert 5-methylcytosine (5mC) preferentially in a CpG context into 5-hydroxymethylcytosine (5hmC) and higher oxidized forms, thereby initiating DNA demethylation, but details regarding the effects of the DNA sequences flanking the target 5mC site on TET activity are unknown. We investigated oxidation of libraries of DNA substrates containing one 5mC or 5hmC residue in randomized sequence context using single molecule readout of oxidation activity and sequence and show pronounced 20 and 70-fold flanking sequence effects on the catalytic activities of TET1 and TET2, respectively. Flanking sequence preferences were similar for TET1 and TET2 and also for 5mC and 5hmC substrates. Enhanced flanking sequence preferences were observed at non-CpG sites together with profound effects of flanking sequences on the specificity of TET2. TET flanking sequence preferences are reflected in genome-wide and local patterns of 5hmC and DNA demethylation in human and mouse cells indicating that they influence genomic DNA modification patterns in combination with locus specific targeting of TET enzymes.', 'entrytype': 'article', 'author': 'Adam, Sabrina and Br{\\"a}cker, Julia and Klingel, Viviane and Osteresch, Bernd and Radde, Nicole E. and Brockmeyer, Jens and Bashtrykov, Pavel and Jeltsch, Albert', 'journal': 'Communications Biology', 'number': '1', 'pages': '92', 'volume': '5', 'day': '24', 'month': 'jan', 'year': '2022', 'url': 'https://doi.org/10.1038/s42003-022-03033-4', 'intrahash': '7414dadd582d56d545f5b8b6bcdf317e', 'interhash': '9c1188e0636c1a7876fa6b1fdc2e9ea7', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/7414dadd582d56d545f5b8b6bcdf317e'}, title='Flanking sequences influence the activity of TET1 and TET2 methylcytosine dioxygenases and affect genomic 5hmC patterns', user='simtech', author='Adam, Sabrina and Br{\\"a}cker, Julia and Klingel, Viviane and Osteresch, Bernd and Radde, Nicole E. and Brockmeyer, Jens and Bashtrykov, Pavel and Jeltsch, Albert', entrytype='article', tag=['exc2075', 'from:vivianeklingel', 'graduateschool', 'myown', 'peerreviewed', 'pn2'], journal='Communications Biology', preprint_id=None, url='https://doi.org/10.1038/s42003-022-03033-4', doi='10.1038/s42003-022-03033-4', isbn=None, issn='2399-3642', misc=None),
#  PUMAEntry(bibtex={'title': 'Determining dissipativity for nonlinear systems from noisy data using Taylor polynomial approximation', 'bibtexKey': 'ist:martin22a', 'entrytype': 'inproceedings', 'address': 'Atlanta, GA, USA', 'author': 'Martin, T. and Allg{\\"o}wer, F.', 'booktitle': 'Proc. American Control Conf. (ACC)', 'pages': '1432-1437', 'year': '2022', 'intrahash': '8c27bcac9a0aa9142e7ee212ad6afb7f', 'interhash': '675982881005d419742e021277318876', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/8c27bcac9a0aa9142e7ee212ad6afb7f'}, title='Determining dissipativity for nonlinear systems from noisy data using Taylor polynomial approximation', user='simtech', author='Martin, T. and Allg{\\"o}wer, F.', entrytype='inproceedings', tag=['EXC2075', 'from:timmartin', 'pn4'], journal=None, preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'A Method to Derive Structural Information on Molecules from Residual Dipolar Coupling {NMR} Data', 'bibtexKey': 'van_Gunsteren_2022', 'misc': '  doi = {10.1021/acs.jpcb.2c02410}', 'entrytype': 'article', 'author': 'van Gunsteren, Wilfred F. and Pechlaner, Maria and Smith, Lorna J. and Stankiewicz, Bartosz and Hansen, Niels', 'journal': 'The Journal of Physical Chemistry B', 'number': '21', 'pages': '3867--3888', 'publisher': 'American Chemical Society ({ACS})', 'volume': '126', 'month': 'may', 'year': '2022', 'url': 'https://doi.org/10.1021%2Facs.jpcb.2c02410', 'intrahash': 'a97ea02e0f537d0f8a1cc0e0eebbebf0', 'interhash': '6d430478ea6bd9a47a73e8af3f67a1fe', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/a97ea02e0f537d0f8a1cc0e0eebbebf0'}, title='A Method to Derive Structural Information on Molecules from Residual Dipolar Coupling {NMR} Data', user='simtech', author='van Gunsteren, Wilfred F. and Pechlaner, Maria and Smith, Lorna J. and Stankiewicz, Bartosz and Hansen, Niels', entrytype='article', tag=['exc2075', 'from:niels_hansen', 'peerreviewed', 'pn3'], journal='The Journal of Physical Chemistry B', preprint_id=None, url='https://doi.org/10.1021%2Facs.jpcb.2c02410', doi='10.1021/acs.jpcb.2c02410', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Exploring the Effect of Enhanced Sampling on Protein Stability Prediction', 'bibtexKey': 'Markthaler_2022', 'misc': '  doi = {10.1021/acs.jctc.1c01012}', 'entrytype': 'article', 'author': 'Markthaler, Daniel and Fleck, Maximilian and Stankiewicz, Bartosz and Hansen, Niels', 'journal': 'Journal of Chemical Theory and Computation', 'number': '4', 'pages': '2569--2583', 'publisher': 'American Chemical Society ({ACS})', 'volume': '18', 'month': 'mar', 'year': '2022', 'url': 'https://doi.org/10.1021%2Facs.jctc.1c01012', 'intrahash': '6518bc8b1e937b748ab0d5d3b898fb74', 'interhash': '55461b38cf06b35c79511c091710ba2c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/6518bc8b1e937b748ab0d5d3b898fb74'}, title='Exploring the Effect of Enhanced Sampling on Protein Stability Prediction', user='simtech', author='Markthaler, Daniel and Fleck, Maximilian and Stankiewicz, Bartosz and Hansen, Niels', entrytype='article', tag=['exc2075', 'from:niels_hansen', 'peerreviewed', 'pn3'], journal='Journal of Chemical Theory and Computation', preprint_id=None, url='https://doi.org/10.1021%2Facs.jctc.1c01012', doi='10.1021/acs.jctc.1c01012', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Influence of layer slipping on adsorption of light gases in covalent organic frameworks: A combined experimental and computational study', 'bibtexKey': 'Kessler_2022', 'misc': '  doi = {10.1016/j.micromeso.2022.111796}', 'entrytype': 'article', 'author': 'Kessler, Christopher and Schuldt, Robin and Emmerling, Sebastian and Lotsch, Bettina V. and Kästner, Johannes and Gross, Joachim and Hansen, Niels', 'journal': 'Microporous and Mesoporous Materials', 'pages': '111796', 'publisher': 'Elsevier {BV}', 'volume': '336', 'month': 'may', 'year': '2022', 'url': 'https://doi.org/10.1016%2Fj.micromeso.2022.111796', 'intrahash': '99316a8c6297e7336ade6220aa16d81a', 'interhash': '3ff3aa1f4e50754d9131f36bbd4a5770', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/99316a8c6297e7336ade6220aa16d81a'}, title='Influence of layer slipping on adsorption of light gases in covalent organic frameworks: A combined experimental and computational study', user='simtech', author='Kessler, Christopher and Schuldt, Robin and Emmerling, Sebastian and Lotsch, Bettina V. and Kästner, Johannes and Gross, Joachim and Hansen, Niels', entrytype='article', tag=['exc2075', 'from:niels_hansen', 'peerreviewed', 'pn3'], journal='Microporous and Mesoporous Materials', preprint_id=None, url='https://doi.org/10.1016%2Fj.micromeso.2022.111796', doi='10.1016/j.micromeso.2022.111796', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Molecular dynamics simulation or structure refinement of proteins: are solvent molecules required? A case study using hen lysozyme', 'bibtexKey': 'Pechlaner2022', 'misc': '  issn = {1432-1017},\n  doi = {10.1007/s00249-022-01593-1}', 'bibtexAbstract': 'In protein simulation or structure refinement based on values of observable quantities measured in (aqueous) solution, solvent (water) molecules may be explicitly treated, omitted, or represented by a potential of mean-solvation-force term, depending on protein coordinates only, in the force field used. These three approaches are compared for hen egg white lysozyme (HEWL). This 129-residue non-spherical protein contains a variety of secondary-structure elements, and ample experimental data are available: 1630 atom--atom Nuclear Overhauser Enhancement (NOE) upper distance bounds, 213 3\xa0J-couplings and 200 S2 order parameters. These data are used to compare the performance of the three approaches. It is found that a molecular dynamics (MD) simulation in explicit water approximates the experimental data much better than stochastic dynamics (SD) simulation in vacuo without or with a solvent-accessible-surface-area (SASA) implicit-solvation term added to the force field. This is due to the missing energetic and entropic contributions and hydrogen-bonding capacities of the water molecules and the missing dielectric screening effect of this high-permittivity solvent. Omission of explicit water molecules leads to compaction of the protein, an increased internal strain, distortion of exposed loop and turn regions and excessive intra-protein hydrogen bonding. As a consequence, the conformation and dynamics of groups on the surface of the protein, which may play a key role in protein--protein interactions or ligand or substrate binding, may be incorrectly modelled. It is thus recommended to include water molecules explicitly in structure refinement of proteins in aqueous solution based on nuclear magnetic resonance (NMR) or other experimentally measured data.', 'entrytype': 'article', 'author': 'Pechlaner, Maria and van Gunsteren, Wilfred F. and Hansen, Niels and Smith, Lorna J.', 'journal': 'European Biophysics Journal', 'number': '3', 'pages': '265--282', 'volume': '51', 'day': '01', 'month': 'apr', 'year': '2022', 'url': 'https://doi.org/10.1007/s00249-022-01593-1', 'intrahash': '79155f07115d2aaa101b6cb2372a62ed', 'interhash': '5efe66a75d04517b45f27af45a87399c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/79155f07115d2aaa101b6cb2372a62ed'}, title='Molecular dynamics simulation or structure refinement of proteins: are solvent molecules required? A case study using hen lysozyme', user='simtech', author='Pechlaner, Maria and van Gunsteren, Wilfred F. and Hansen, Niels and Smith, Lorna J.', entrytype='article', tag=['exc2075', 'from:niels_hansen', 'peerreviewed', 'pn3'], journal='European Biophysics Journal', preprint_id=None, url='https://doi.org/10.1007/s00249-022-01593-1', doi='10.1007/s00249-022-01593-1', isbn=None, issn='1432-1017', misc=None),
#  PUMAEntry(bibtex={'title': 'Umbrella sampling and double decoupling data for methanol binding to Candida antarctica lipase B', 'bibtexKey': 'Markthaler_2021', 'misc': '  doi = {10.1016/j.dib.2021.107618}', 'entrytype': 'article', 'author': 'Markthaler, Daniel and Hansen, Niels', 'journal': 'Data in Brief', 'pages': '107618', 'publisher': 'Elsevier {BV}', 'volume': '39', 'month': 'dec', 'year': '2021', 'url': 'https://doi.org/10.1016%2Fj.dib.2021.107618', 'intrahash': '008bc983556047cc0d4e99d112453b81', 'interhash': '29b6bc5fae457facb64be8687914c765', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/008bc983556047cc0d4e99d112453b81'}, title='Umbrella sampling and double decoupling data for methanol binding to Candida antarctica lipase B', user='simtech', author='Markthaler, Daniel and Hansen, Niels', entrytype='article', tag=['exc2075', 'from:niels_hansen', 'myown', 'peerReviewed', 'pn3', 'pn3-8send:unibiblio'], journal='Data in Brief', preprint_id=None, url='https://doi.org/10.1016%2Fj.dib.2021.107618', doi='10.1016/j.dib.2021.107618', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Certified machine learning: A posteriori error estimation for physics-informed neural networks', 'bibtexKey': 'HilU22', 'misc': '  pubdate = {2022-03-31}', 'bibtexAbstract': 'Physics-informed neural networks (PINNs) are one popular approach to introduce a priori knowledge about physical systems into the learning framework. PINNs are known to be robust for smaller training sets, derive better generalization problems, and are faster to train. In this paper, we show that using PINNs in comparison with purely data-driven neural networks is not only favorable for training performance but allows us to extract significant information on the quality of the approximated solution. Assuming that the underlying differential equation for the PINN training is an ordinary differential equation, we derive a rigorous upper limit on the PINN prediction error. This bound is applicable even for input data not included in the training phase and without any prior knowledge about the true solution. Therefore, our a posteriori error estimation is an essential step to certify the PINN. We apply our error estimator exemplarily to two academic toy problems, whereof one falls in the category of model-predictive control and thereby shows the practical use of the derived results.', 'entrytype': 'article', 'author': 'Hillebrecht, Birgit and Unger, Benjamin', 'journal': 'ArXiv e-print 2203.17055', 'year': '2022', 'url': 'http://arxiv.org/abs/2203.17055', 'intrahash': '10a0f19dc3d4adaa8c4ef8fcbcd18359', 'interhash': '4304a67819c757c85c5b19e1eec97200', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/10a0f19dc3d4adaa8c4ef8fcbcd18359'}, title='Certified machine learning: A posteriori error estimation for physics-informed neural networks', user='simtech', author='Hillebrecht, Birgit and Unger, Benjamin', entrytype='article', tag=['exc2075', 'from:benjaminunger', 'myown', 'pn4', 'preprint'], preprint_id={'type': 'arxiv', 'id': '2203.17055'}, journal='ArXiv e-print 2203.17055', url='http://arxiv.org/abs/2203.17055', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Composing Partial Differential Equations with Physics-Aware Neural Networks', 'bibtexKey': 'karlbauer2021composing', 'entrytype': 'inproceedings', 'address': 'Baltimore, USA', 'author': 'Karlbauer, Matthias and Praditia, Timothy and Otte, Sebastian and Oladyshkin, Sergey and Nowak, Wolfgang and Butz, Martin V', 'booktitle': 'Proceedings of the 39th International Conference on Machine Learning', 'series': 'Proceedings of Machine Learning Research', 'month': '16--23 Jul', 'year': '2022', 'intrahash': 'e47b54551c3d1d87ac63ae9f4306b4cd', 'interhash': '81b29779ff7591cc685ceb36fe671d1c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/e47b54551c3d1d87ac63ae9f4306b4cd'}, title='Composing Partial Differential Equations with Physics-Aware Neural Networks', user='simtech', author='Karlbauer, Matthias and Praditia, Timothy and Otte, Sebastian and Oladyshkin, Sergey and Nowak, Wolfgang and Butz, Martin V', entrytype='inproceedings', tag=['EXC2075', 'from:timothypraditia'], journal=None, preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Documenting research software in engineering science', 'bibtexKey': 'hermann2022documenting', 'misc': '  issn = {2045-2322},\n  doi = {10.1038/s41598-022-10376-9}', 'bibtexAbstract': 'The reuse of research software needs good documentation, however, the documentation in particular is often criticized. Especially in non-IT specific disciplines, the lack of documentation is attributed to the lack of training, the lack of time or missing rewards. This article addresses the hypothesis that scientists do document but do not know exactly what they need to document, why, and for whom. In order to evaluate the actual documentation practice of research software, we examined existing recommendations, and we evaluated their implementation in everyday practice using a concrete example from the engineering sciences and compared the findings with best practice examples. To get a broad overview of what documentation of research software entailed, we defined categories and used them to conduct the research. Our results show that the big picture of what documentation of research software means is missing. Recommendations do not consider the important role of researchers, who write research software, whose documentation takes mainly place in their research articles. Moreover, we show that research software always has a history that influences the documentation.', 'entrytype': 'article', 'author': 'Hermann, Sibylle and Fehr, Jörg', 'journal': 'Scientific Reports', 'number': '1', 'pages': '6567', 'volume': '12', 'day': '21', 'month': 'apr', 'year': '2022', 'url': 'https://doi.org/10.1038/s41598-022-10376-9', 'intrahash': 'ee4ea2e8ba09366e560cb09a23eeb898', 'interhash': '1307417c9c2edce990bba5404c653003', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/ee4ea2e8ba09366e560cb09a23eeb898'}, title='Documenting research software in engineering science', user='simtech', author='Hermann, Sibylle and Fehr, Jörg', entrytype='article', tag=['EXC2075', 'PNX', 'from:hermann', 'graduateSchool'], journal='Scientific Reports', preprint_id=None, url='https://doi.org/10.1038/s41598-022-10376-9', doi='10.1038/s41598-022-10376-9', isbn=None, issn='2045-2322', misc=None),
#  PUMAEntry(bibtex={'title': '{Mitochondrial genome variations, mitochondrial-nuclear compatibility, and their association with metabolic diseases}', 'bibtexKey': 'Ludwig-Somczynska2022', 'misc': '  issn = {1930-739X},\n  doi = {10.1002/OBY.23424}', 'entrytype': 'article', 'author': "Ludwig-S{\\l}omczy{\\'{n}}ska, Agnieszka H. and Rehm, Markus", 'journal': 'Obesity', 'publisher': 'John Wiley & Sons, Ltd', 'month': 'may', 'year': '2022', 'url': 'https://onlinelibrary.wiley.com/doi/full/10.1002/oby.23424', 'intrahash': '0c871f621cfa1fab82d48a1fbeea7d5e', 'interhash': '09e034bb54deccb6ae7d294f7f3efca5', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/0c871f621cfa1fab82d48a1fbeea7d5e'}, title='{Mitochondrial genome variations, mitochondrial-nuclear compatibility, and their association with metabolic diseases}', user='simtech', author="Ludwig-S{\\l}omczy{\\'{n}}ska, Agnieszka H. and Rehm, Markus", entrytype='article', tag=['2022', 'EXC2075', 'from:cristiano', 'izi', 'morrison', 'pn2', 'simtech'], journal='Obesity', preprint_id=None, url='https://onlinelibrary.wiley.com/doi/full/10.1002/oby.23424', doi='10.1002/oby.23424', isbn=None, issn='1930-739x', misc=None),
#  PUMAEntry(bibtex={'title': 'Reduced Basis Methods for\xa0Efficient Simulation of\xa0a\xa0Rigid Robot Hand Interacting with\xa0Soft Tissue', 'bibtexKey': 'shuva2022reduced', 'misc': '  isbn = {978-3-030-97549-4}', 'bibtexAbstract': 'We present efficient reduced basis (RB) methods for the simulation of a coupled problem consisting of a rigid robot hand interacting with soft tissue material. The soft tissue is modeled by the linear elasticity equation and discretized with the Finite Element Method. We look at two different scenarios: (i) the forward simulation and (ii) a feedback control formulation of the model. In both cases, large-scale systems of equations appear, which need to be solved in real-time. This is essential in practice for the implementation in a real robot. For the feedback-scenario, we encounter a high-dimensional Algebraic Riccati Equation (ARE) in the context of the linear quadratic regulator. To overcome the real-time constraint by significantly reducing the computational complexity, we use several structure-preserving and non-structure-preserving reduction methods. These include reduced basis techniques based on the Proper Orthogonal Decomposition. For the ARE, we compute a low-rank-factor and hence solve a low-dimensional ARE instead of solving a full dimensional problem. Numerical examples for both cases (i) and (ii) are provided. These illustrate the approximation quality of the reduced solution and speedup factors of the different reduction approaches.', 'entrytype': 'inproceedings', 'author': 'Shuva, Shahnewaz and Buchfink, Patrick and Röhrle, Oliver and Haasdonk, Bernard', 'booktitle': 'Large-Scale Scientific Computing', 'editor': 'Lirkov, Ivan and Margenov, Svetozar', 'pages': '402--409', 'publisher': 'Springer International Publishing', 'year': '2022', 'intrahash': '5b89403a8f724160194492c3d4a310f7', 'interhash': '265d41292d6ac75fea2eea1080339eb2', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/5b89403a8f724160194492c3d4a310f7'}, title='Reduced Basis Methods for\xa0Efficient Simulation of\xa0a\xa0Rigid Robot Hand Interacting with\xa0Soft Tissue', user='simtech', author='Shuva, Shahnewaz and Buchfink, Patrick and Röhrle, Oliver and Haasdonk, Bernard', entrytype='inproceedings', tag=['EXC2075', 'from:patrickbuchfink', 'ians', 'myown', 'peerReviewed', 'pn5'], journal=None, preprint_id=None, url=None, doi=None, isbn='978-3-030-97549-4', issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Inferring Boundary Conditions in Finite Volume Neural Networks', 'bibtexKey': 'horuz2022submittedinferring', 'entrytype': 'inproceedings', 'author': 'Horuz, Co{\\c{s}}ku Can and Karlbauer, Matthias and Praditia, Timothy and Butz, Martin V. and Oladyshkin, Sergey and Nowak, Wolfgang and Otte, Sebastian', 'booktitle': 'International Conference on Artificial Neural Networks 2022', 'year': '2022 (submitted)', 'intrahash': '74ea1861d8fb4a37fce247357747f12f', 'interhash': 'b5d92106241882309b2850a83d0963ba', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/74ea1861d8fb4a37fce247357747f12f'}, title='Inferring Boundary Conditions in Finite Volume Neural Networks', user='simtech', author='Horuz, Co{\\c{s}}ku Can and Karlbauer, Matthias and Praditia, Timothy and Butz, Martin V. and Oladyshkin, Sergey and Nowak, Wolfgang and Otte, Sebastian', entrytype='inproceedings', tag=['2', 'EXC2075', 'IWSABT:ls3', 'IWSAUTHOR:NowakWolfgang', 'IWSAUTHOR:OladyshkinSergey', 'IWSAUTHOR:PraditiaTimothy', 'IWSMONTH:12', 'IWSSUBTYPE:inproceedings', 'IWSTYPEDE:Konferenzbeiträge', 'IWSTYPEEN:contribution_to_edited_volumes', 'IWSTYPENR:3', 'IWSYEAR:2022', 'from:timothypraditia', 'peerreviewed', 'pn5'], journal=None, preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Structured Deep Kernel Networks for\xa0Data-Driven Closure Terms of\xa0Turbulent Flows', 'bibtexKey': 'wenzel2022structured', 'misc': '  isbn = {978-3-030-97549-4}', 'bibtexAbstract': 'Standard kernel methods for machine learning usually struggle when dealing with large datasets. We review a recently introduced Structured Deep Kernel Network (SDKN) approach that is capable of dealing with high-dimensional and huge datasets - and enjoys typical standard machine learning approximation properties.', 'entrytype': 'inproceedings', 'address': 'Cham', 'author': 'Wenzel, Tizian and Kurz, Marius and Beck, Andrea and Santin, Gabriele and Haasdonk, Bernard', 'booktitle': 'Large-Scale Scientific Computing', 'editor': 'Lirkov, Ivan and Margenov, Svetozar', 'pages': '410--418', 'publisher': 'Springer International Publishing', 'year': '2022', 'intrahash': '43a04ad795d27a498a944a5fa0492d71', 'interhash': '4d5fe46232a8071066356f28243f3701', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/43a04ad795d27a498a944a5fa0492d71'}, title='Structured Deep Kernel Networks for\xa0Data-Driven Closure Terms of\xa0Turbulent Flows', user='simtech', author='Wenzel, Tizian and Kurz, Marius and Beck, Andrea and Santin, Gabriele and Haasdonk, Bernard', entrytype='inproceedings', tag=['exc2075', 'from:tizianwenzel', 'ians', 'myown', 'peerreviewed', 'pn6', 'pn6-1'], journal=None, preprint_id=None, url=None, doi=None, isbn='978-3-030-97549-4', issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Stability of convergence rates: Kernel interpolation on non-Lipschitz domains', 'bibtexKey': 'wenzel2022stability', 'misc': '  copyright = {arXiv.org perpetual, non-exclusive license},\n  doi = {10.48550/ARXIV.2203.12532}', 'entrytype': 'misc', 'author': 'Wenzel, Tizian and Santin, Gabriele and Haasdonk, Bernard', 'publisher': 'arXiv', 'year': '2022', 'url': 'https://arxiv.org/abs/2203.12532', 'intrahash': '2310f782f118011ea7ac1728cc7adeed', 'interhash': '20a02f7b37cf3e375c29d86ac044b511', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/2310f782f118011ea7ac1728cc7adeed'}, title='Stability of convergence rates: Kernel interpolation on non-Lipschitz domains', user='simtech', author='Wenzel, Tizian and Santin, Gabriele and Haasdonk, Bernard', entrytype='misc', tag=['exc2075', 'from:tizianwenzel', 'ians', 'myown', 'pn6', 'pn6-1'], journal=None, preprint_id={'type': 'arxiv', 'id': '2203.12532'}, url='https://arxiv.org/abs/2203.12532', doi='10.48550/arxiv.2203.12532', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Analysis of target data-dependent greedy kernel algorithms: Convergence rates for $f$-, $f \\cdot P$- and $f/P$-greedy', 'bibtexKey': 'wenzel2021analysis', 'misc': '  copyright = {arXiv.org perpetual, non-exclusive license},\n  doi = {10.48550/ARXIV.2105.07411}', 'entrytype': 'misc', 'author': 'Wenzel, Tizian and Santin, Gabriele and Haasdonk, Bernard', 'publisher': 'arXiv', 'year': '2021', 'url': 'https://arxiv.org/abs/2105.07411', 'intrahash': 'a64153579e1bd67d268231389802485b', 'interhash': '98d1b32947f0e619453e0a71e18e3b3d', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/a64153579e1bd67d268231389802485b'}, title='Analysis of target data-dependent greedy kernel algorithms: Convergence rates for $f$-, $f \\cdot P$- and $f/P$-greedy', user='simtech', author='Wenzel, Tizian and Santin, Gabriele and Haasdonk, Bernard', entrytype='misc', tag=['exc2075', 'from:tizianwenzel', 'ians', 'myown', 'pn6', 'pn6-1'], journal=None, preprint_id={'type': 'arxiv', 'id': '2105.07411'}, url='https://arxiv.org/abs/2105.07411', doi='10.48550/arxiv.2105.07411', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'A Full Order, Reduced Order and\xa0Machine Learning Model Pipeline for\xa0Efficient Prediction of\xa0Reactive Flows', 'bibtexKey': 'gavrilenko2022order', 'misc': '  isbn = {978-3-030-97549-4}', 'bibtexAbstract': 'We present an integrated approach for the use of simulated data from full order discretization as well as projection-based Reduced Basis reduced order models for the training of machine learning approaches, in particular Kernel Methods, in order to achieve fast, reliable predictive models for the chemical conversion rate in reactive flows with varying transport regimes.', 'entrytype': 'inproceedings', 'address': 'Cham', 'author': 'Gavrilenko, Pavel and Haasdonk, Bernard and Iliev, Oleg and Ohlberger, Mario and Schindler, Felix and Toktaliev, Pavel and Wenzel, Tizian and Youssef, Maha', 'booktitle': 'Large-Scale Scientific Computing', 'editor': 'Lirkov, Ivan and Margenov, Svetozar', 'pages': '378--386', 'publisher': 'Springer International Publishing', 'year': '2022', 'intrahash': '918f84b215506197a18d55d6c0e130da', 'interhash': 'b3f223235af91c94685ca80f690ff321', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/918f84b215506197a18d55d6c0e130da'}, title='A Full Order, Reduced Order and\xa0Machine Learning Model Pipeline for\xa0Efficient Prediction of\xa0Reactive Flows', user='simtech', author='Gavrilenko, Pavel and Haasdonk, Bernard and Iliev, Oleg and Ohlberger, Mario and Schindler, Felix and Toktaliev, Pavel and Wenzel, Tizian and Youssef, Maha', entrytype='inproceedings', tag=['exc2075', 'from:tizianwenzel', 'ians', 'myown', 'peerreviewed', 'pn6', 'pn6-1'], journal=None, preprint_id=None, url=None, doi=None, isbn='978-3-030-97549-4', issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Biomechanical Surrogate Modelling Using Stabilized Vectorial Greedy Kernel Methods', 'bibtexKey': 'haasdonk2021biomechanical', 'misc': '  isbn = {978-3-030-55874-1}', 'entrytype': 'inproceedings', 'address': 'Cham', 'author': 'Haasdonk, Bernard and Wenzel, Tizian and Santin, Gabriele and Schmitt, Syn', 'booktitle': 'Numerical Mathematics and Advanced Applications ENUMATH 2019', 'editor': 'Vermolen, Fred J. and Vuik, Cornelis', 'pages': '499--508', 'publisher': 'Springer International Publishing', 'year': '2021', 'intrahash': 'fdf25bbd8529868d74f790eb07299ef8', 'interhash': 'd52b37477dd0f03087e7d4dbdc41ad60', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/fdf25bbd8529868d74f790eb07299ef8'}, title='Biomechanical Surrogate Modelling Using Stabilized Vectorial Greedy Kernel Methods', user='simtech', author='Haasdonk, Bernard and Wenzel, Tizian and Santin, Gabriele and Schmitt, Syn', entrytype='inproceedings', tag=['EXC2075', 'from:tizianwenzel', 'ians', 'myown', 'peerReviewed', 'pn6-1'], journal=None, preprint_id=None, url=None, doi=None, isbn='978-3-030-55874-1', issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'RfX: A Design Study for the Interactive Exploration of a Random Forest to Enhance Testing Procedures for Electrical Engines', 'bibtexKey': 'noauthororeditor2022design', 'misc': '  issn = {0167-7055},\n  doi = {https://doi.org/10.1111/cgf.14452}', 'entrytype': 'article', 'author': 'Eirich, L and Münch, M. and Jäckle, D. and Sedlmair, M. and Bonart, J. and Schreck, T.', 'journal': 'Computer Graphics Forum (CGF)', 'pages': '14', 'year': '2022', 'intrahash': 'ffed71197eb66b630c490e498f599c31', 'interhash': '159f41614963cdf47f13ce2b1b81e9df', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/ffed71197eb66b630c490e498f599c31'}, title='RfX: A Design Study for the Interactive Exploration of a Random Forest to Enhance Testing Procedures for Electrical Engines', user='simtech', author='Eirich, L and Münch, M. and Jäckle, D. and Sedlmair, M. and Bonart, J. and Schreck, T.', entrytype='article', tag=['EXC2075', 'EXC2075(from2019)', 'exc2075', 'exc2075(from2019)', 'from:xingyaoyu', 'simtech', 'visus:sedlmaml'], journal='Computer Graphics Forum (CGF)', preprint_id=None, url=None, doi='10.1111/cgf.14452', isbn=None, issn='0167-7055', misc=None),
#  PUMAEntry(bibtex={'title': 'RfX: A Design Study for the Interactive Exploration of a Random Forest to Enhance Testing Procedures for Electrical Engines', 'bibtexKey': 'noauthororeditor2022design', 'entrytype': 'article', 'author': 'Eirich, L and Münch, M. and Jäckle, D. and Sedlmair, M. and Bonart, J. and Schreck, T.', 'year': '2022', 'intrahash': 'bf4ed0a30961ed37974bb75c8e20d8af', 'interhash': '159f41614963cdf47f13ce2b1b81e9df', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/bf4ed0a30961ed37974bb75c8e20d8af'}, title='RfX: A Design Study for the Interactive Exploration of a Random Forest to Enhance Testing Procedures for Electrical Engines', user='simtech', author='Eirich, L and Münch, M. and Jäckle, D. and Sedlmair, M. and Bonart, J. and Schreck, T.', entrytype='article', tag=['EXC2075', 'EXC2075(from2019)', 'exc2075', 'exc2075(from2019)', 'from:xingyaoyu', 'simtech', 'visus:sedlmaml'], journal=None, preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'MolecuSense: Using Force-Feedback Gloves for Creating and Interacting\r\n  with Ball-and-Stick Molecules in VR', 'bibtexKey': 'gebhardt2022molecusense', 'bibtexAbstract': 'We contribute MolecuSense, a virtual version of a physical molecule\r\nconstruction kit, based on visualization in Virtual Reality (VR) and\r\ninteraction with force-feedback gloves. Targeting at chemistry education, our\r\ngoal is to make virtual molecule structures more tangible. Results of an\r\ninitial user study indicate that the VR molecular construction kit was\r\npositively received. Compared to a physical construction kit, the VR molecular\r\nconstruction kit is on the same level in terms of natural interaction. Besides,\r\nit fosters the typical digital advantages though, such as saving, exporting,\r\nand sharing of molecules. Feedback from the study participants has also\r\nrevealed potential future avenues for tangible molecule visualizations.', 'entrytype': 'misc', 'author': 'Gebhardt, Patrick and Yu, Xingyao and Köhn, Andreas and Sedlmair, Michael', 'note': 'cite arxiv:2203.09577Comment: 4 pages,4 figures', 'year': '2022', 'url': 'http://arxiv.org/abs/2203.09577', 'intrahash': '54ac953d4981c9cbef8ff498ca30e59a', 'interhash': '1accfcc7c6674ce6c6b8c00162b5daf1', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/54ac953d4981c9cbef8ff498ca30e59a'}, title='MolecuSense: Using Force-Feedback Gloves for Creating and Interacting\r\n  with Ball-and-Stick Molecules in VR', user='simtech', author='Gebhardt, Patrick and Yu, Xingyao and Köhn, Andreas and Sedlmair, Michael', entrytype='misc', tag=['exc2075', 'exc2075(from2019)', 'from:xingyaoyu', 'myown', 'simtech', 'vis(us)', 'visus', 'visus:sedlmaml', 'visus:yuxo'], journal=None, preprint_id={'type': 'arxiv', 'id': '2203.09577'}, url='http://arxiv.org/abs/2203.09577', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Symplectic Model Reduction of Hamiltonian Systems on Nonlinear Manifolds', 'bibtexKey': 'buchfink2021symplectic', 'misc': '  doi = {https://doi.org/10.48550/arXiv.2112.10815}', 'entrytype': 'misc', 'author': 'Buchfink, Patrick and Glas, Silke and Haasdonk, Bernard', 'howpublished': 'preprint', 'year': '2021', 'url': 'https://arxiv.org/abs/2112.10815', 'intrahash': '2035ec699a2389498468be6a091bfb69', 'interhash': '20d1d3e65a84ec3522d62ed34fd66c21', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/2035ec699a2389498468be6a091bfb69'}, title='Symplectic Model Reduction of Hamiltonian Systems on Nonlinear Manifolds', user='simtech', author='Buchfink, Patrick and Glas, Silke and Haasdonk, Bernard', entrytype='misc', tag=['exc2075', 'from:patrickbuchfink', 'myown', 'pn5', 'prePrint'], journal=None, preprint_id={'type': 'arxiv', 'id': '2112.10815'}, url='https://arxiv.org/abs/2112.10815', doi='10.48550/arxiv.2112.10815', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Mesh generation and multi-scale simulation of a contracting muscle–tendon complex', 'bibtexKey': 'MAIER2022101559', 'misc': '  issn = {1877-7503},\n  doi = {https://doi.org/10.1016/j.jocs.2022.101559}', 'bibtexAbstract': 'The multi-scale character of skeletal muscle models requires simulations with high spatial resolution to capture all relevant effects. This naturally involves high computational load that can only be tackled by parallel computations. We simulate electrophysiology and muscle contraction using a state-of-the-art, biophysical chemo-electro-mechanical model that requires meshes of the 3D domain with embedded, aligned 1D meshes for muscle fibers. We present novel algorithms to construct highly-resolved meshes with robust properties for real muscle geometries from surface triangulations. We demonstrate their use and suitability in a simulation of the biceps brachii muscle and tendons. In addition, the respective simulations showcase several functional enhancements of our simulation framework OpenDiHu.', 'entrytype': 'article', 'author': 'Maier, Benjamin and Schulte, Miriam', 'journal': 'Journal of Computational Science', 'pages': '101559', 'volume': '59', 'year': '2022', 'url': 'https://www.sciencedirect.com/science/article/pii/S1877750322000023', 'intrahash': '08ce9f737711883e6b2a31df3897cf18', 'interhash': '4828caea2bf3a6b5b495649b6b2c7e22', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/08ce9f737711883e6b2a31df3897cf18'}, title='Mesh generation and multi-scale simulation of a contracting muscle–tendon complex', user='simtech', author='Maier, Benjamin and Schulte, Miriam', entrytype='article', tag=['exc2075', 'from:miriammehl', 'miriammehl', 'myown', 'pn5'], journal='Journal of Computational Science', preprint_id=None, url='https://www.sciencedirect.com/science/article/pii/S1877750322000023', doi='10.1016/j.jocs.2022.101559', isbn=None, issn='1877-7503', misc=None),
#  PUMAEntry(bibtex={'title': 'Port-Hamiltonian Fluid-Structure Interaction Modeling and Structure-Preserving Model Order Reduction of a Classical Guitar', 'bibtexKey': 'rettberg2022porthamiltonian', 'misc': '  doi = {https://doi.org/10.48550/arXiv.2203.10061}', 'entrytype': 'misc', 'author': 'Rettberg, Johannes and Wittwar, Dominik and Buchfink, Patrick and Brauchler, Alexander and Ziegler, Pascal and Fehr, Jörg and Haasdonk, Bernard', 'howpublished': 'preprint', 'year': '2022', 'url': 'https://arxiv.org/abs/2203.10061', 'intrahash': '84c2f518a99b2627125725831f1c14eb', 'interhash': 'ecfc092a30045210b7013216462d94cf', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/84c2f518a99b2627125725831f1c14eb'}, title='Port-Hamiltonian Fluid-Structure Interaction Modeling and Structure-Preserving Model Order Reduction of a Classical Guitar', user='simtech', author='Rettberg, Johannes and Wittwar, Dominik and Buchfink, Patrick and Brauchler, Alexander and Ziegler, Pascal and Fehr, Jörg and Haasdonk, Bernard', entrytype='misc', tag=['exc2075', 'pn5', 'pn7', 'prePrint'], journal=None, preprint_id={'type': 'arxiv', 'id': '2203.10061'}, url='https://arxiv.org/abs/2203.10061', doi='10.48550/arxiv.2203.10061', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Predicting properties of periodic systems from cluster data: A case study of liquid water', 'bibtexKey': 'doi:10.1063/5.0078983', 'misc': '  eprint = {https://doi.org/10.1063/5.0078983},\n  doi = {10.1063/5.0078983}', 'bibtexAbstract': ' The accuracy of the training data limits the accuracy of bulk properties from machine-learned potentials. For example, hybrid functionals or wave-function-based quantum chemical methods are readily available for cluster data but effectively out of scope for periodic structures. We show that local, atom-centered descriptors for machine-learned potentials enable the prediction of bulk properties from cluster model training data, agreeing reasonably well with predictions from bulk training data. We demonstrate such transferability by studying structural and dynamical properties of bulk liquid water with density functional theory and have found an excellent agreement with experimental and theoretical counterparts. ', 'entrytype': 'article', 'author': 'Zaverkin, Viktor and Holzmüller, David and Schuldt, Robin and Kästner, Johannes', 'journal': 'The Journal of Chemical Physics', 'number': '11', 'pages': '114103', 'volume': '156', 'year': '2022', 'url': '/brokenurl#         https://doi.org/10.1063/5.0078983    ', 'intrahash': '85f01d8422ba11de633bfdbd113ac8cd', 'interhash': '5a5ed93c5ad2714ceca27d238ddd5dad', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/85f01d8422ba11de633bfdbd113ac8cd'}, title='Predicting properties of periodic systems from cluster data: A case study of liquid water', user='simtech', author='Zaverkin, Viktor and Holzmüller, David and Schuldt, Robin and Kästner, Johannes', entrytype='article', tag=['exc2075', 'from:davidholzmller', 'graduateschool', 'myown', 'peerreviewed', 'pn6'], journal='The Journal of Chemical Physics', preprint_id=None, url='/brokenurl#         https://doi.org/10.1063/5.0078983    ', doi='10.1063/5.0078983', isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'A Framework and Benchmark for Deep Batch Active Learning for Regression', 'bibtexKey': 'holzmueller_framework_2022', 'bibtexAbstract': 'We study the performance of different pool-based Batch Mode Deep Active Learning (BMDAL) methods for regression on tabular data, focusing on methods that do not require to modify the network architecture and training. Our contributions are three-fold: First, we present a framework for constructing BMDAL methods out of kernels, kernel transformations and selection methods, showing that many of the most popular BMDAL methods fit into our framework. Second, we propose new components, leading to a new BMDAL method. Third, we introduce an open-source benchmark with 15 large tabular data sets, which we use to compare different BMDAL methods. Our benchmark results show that a combination of our novel components yields new state-of-the-art results in terms of RMSE and is computationally efficient. We provide open-source code that includes efficient implementations of all kernels, kernel transformations, and selection methods, and can be used for reproducing our results.', 'entrytype': 'article', 'author': 'Holzmüller, David and Zaverkin, Viktor and Kästner, Johannes and Steinwart, Ingo', 'journal': 'arXiv:1112.5745', 'year': '2022', 'intrahash': 'aaf4089f678271f2c1a5eba8e27a75f1', 'interhash': '27fa5d1aa438de56c68c52cc8ccc12d7', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/aaf4089f678271f2c1a5eba8e27a75f1'}, title='A Framework and Benchmark for Deep Batch Active Learning for Regression', user='simtech', author='Holzmüller, David and Zaverkin, Viktor and Kästner, Johannes and Steinwart, Ingo', entrytype='article', tag=['exc2075', 'from:davidholzmller', 'myown', 'pn6', 'preprint'], journal='arXiv:1112.5745', preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Fast Sparse Grid Operations Using the Unidirectional Principle: A Generalized and Unified Framework', 'bibtexKey': '10.1007/978-3-030-81362-8_4', 'misc': '  isbn = {978-3-030-81362-8}', 'bibtexAbstract': 'Sparse grids enable accurate function approximation in higher-dimensional settings with a moderate number of grid points. In this paper, we introduce generalized versions of various efficient sparse grid algorithms in a unified notation: For local basis functions, transformations between function values at grid points and interpolation coefficients can be efficiently realized using the well-known unidirectional principle (Balder and Zenger, SIAM Journal on Scientific Computing, 17(3):631--646, May 1996; Bungartz, Finite Elements of Higher Order on Sparse Grids, Universit{\\"a}t M{\\"u}nchen, Aachen, November 1998). For general basis functions without spatial adaptivity, Avila and Carrington show in (The Journal of Chemical Physics, 143(21):214108, 2015) and follow-up work that the unidirectional principle can instead be applied to an equivalent incremental basis, and we show that a second application of the unidirectional principle can be used to compute interpolation coefficients for the original, non-incremental basis. Our Open Source implementation for the latter case is able to compute interpolation coefficients for up to 20 million sparse grid points in one second on a single CPU core. We also discuss the efficient application of linear operators occurring in derivative evaluations of interpolants and in the solution of partial differential equations on sparse grids with finite elements, e.g., using the UpDown scheme (Bungartz, D{\\"u}nne Gitter und deren Anwendung bei der adaptiven L{\\"o}sung der dreidimensionalen Poisson-Gleichung, PhD thesis, Technische Universit{\\"a}t M{\\"u}nchen, 1992; Pfl{\\"u}ger, Spatially Adaptive Sparse Grids for High-Dimensional Problems, Verlag Dr. Hut, M{\\"u}nchen, February 2010; Zeiser, Journal of Scientific Computing, 47(3):328--346, 2011; Bungartz et al., Journal of Computational and Applied Mathematics, 236(15):3741--3750, 2012).', 'entrytype': 'inproceedings', 'address': 'Cham', 'author': 'Holzm{\\"u}ller, David and Pfl{\\"u}ger, Dirk', 'booktitle': 'Sparse Grids and Applications - Munich 2018', 'editor': 'Bungartz, Hans-Joachim and Garcke, Jochen and Pfl{\\"u}ger, Dirk', 'pages': '69--100', 'publisher': 'Springer International Publishing', 'year': '2021', 'intrahash': '8ec97c3d2425a1399cde9df27c0a9add', 'interhash': '291453abea2da18bc0cb8598039ca4ba', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/8ec97c3d2425a1399cde9df27c0a9add'}, title='Fast Sparse Grid Operations Using the Unidirectional Principle: A Generalized and Unified Framework', user='simtech', author='Holzm{\\"u}ller, David and Pfl{\\"u}ger, Dirk', entrytype='inproceedings', tag=['exc2075', 'from:davidholzmller', 'graduateschool', 'peerreviewed', 'pn6'], journal=None, preprint_id=None, url=None, doi=None, isbn='978-3-030-81362-8', issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'A neural network based shock detection and localization approach for discontinuous Galerkin methods', 'bibtexKey': 'beck2020neural', 'misc': '  doi = {10.1016/j.jcp.2020.109824}', 'bibtexAbstract': 'The stable and accurate approximation of discontinuities such as shocks on a finite computational mesh is a challenging task. Detection of shocks or strong discontinuities in the flow solution is typically achieved through a priori troubled cell indicators, which guide the subsequent action of an appropriate shock capturing mechanism. Arriving at a stable and accurate solution often requires empirically based parameter tuning and adjustments of the indicator settings to the discretization and solution at hand. In this work, we propose to separate the task of shock detection and shock capturing more strongly and aim to develop a shock indicator that is robust, accurate, requires minimal user input and is suitable for high order element-based methods like discontinuous Galerkin and flux reconstruction methods. The novel indicator is learned from analytical data through a supervised learning strategy; its input is given by the high order solution field, its output is an element-local map of the shock position. We use state of the art methods from edge detection in image analysis based on deep convolutional multiscale networks and deep supervision to train the indicators. The resulting networks are then used as black box indicators, showing their robustness and accuracy on well established canonical testcases. All simulations are run ab initio using the developed indicators, showing that they provide also stability during the strongly transient phases. In particular for high order schemes with large cells and considerable inner-cell resolution capabilities, we demonstrate how the additional accurate prediction of the position of the shock front can be exploited to guide inner-element shock capturing strategies.', 'entrytype': 'article', 'author': 'Beck, Andrea D. and Zeifang, Jonas and Schwarz, Anna and Flad, David G.', 'journal': 'Journal of Computational Physics', 'pages': '109824', 'publisher': 'Elsevier', 'volume': '423', 'year': '2020', 'url': 'https://doi.org/10.1016/j.jcp.2020.109824', 'intrahash': '9f617a8e391240d210b5b8723a602012', 'interhash': 'd8b88b37765b0fd753b7b2caa8dc8b38', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/9f617a8e391240d210b5b8723a602012'}, title='A neural network based shock detection and localization approach for discontinuous Galerkin methods', user='simtech', author='Beck, Andrea D. and Zeifang, Jonas and Schwarz, Anna and Flad, David G.', entrytype='article', tag=['EXC2075', 'from:simtechpuma', 'pn1'], journal='Journal of Computational Physics', preprint_id=None, url='https://doi.org/10.1016/j.jcp.2020.109824', doi='10.1016/j.jcp.2020.109824', isbn=None, issn=None, misc=None),
# ...
#  PUMAEntry(bibtex={'title': '{A}n {LPV} control approach to asymptotic rejection of non-stationary disturbances with guaranteed worst-case performance', 'bibtexKey': 'KSch07', 'misc': '  shorttitle = {An LPV control approach to asymptotic rejection of non-stationary disturbances with guaranteed worst-case performance},\n  file = {http://www.scopus.com/scopus/inward/record.file?eid=2-s2.0-46449094638&partnerID=40},\n  endnotereftype = {Conference Proceedings}', 'entrytype': 'inproceedings', 'author': 'K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', 'booktitle': 'Proc. American Control Conf.', 'pages': '6085-6090', 'year': '2007', 'url': 'https://doi.org/10.1109/ACC.2007.4282141', 'intrahash': '452aad96427c8c97e7a25dfe87e3982a', 'interhash': '98ea342dfa33becdde69111fa11a4ba0', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/452aad96427c8c97e7a25dfe87e3982a'}, title='{A}n {LPV} control approach to asymptotic rejection of non-stationary disturbances with guaranteed worst-case performance', user='simtech', author='K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.1109/ACC.2007.4282141', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{V}erifying exactness of relaxations for robust semi-definite programs by solving polynomial systems', 'bibtexKey': 'DieSch08', 'misc': '  shorttitle = {Verifying exactness of relaxations for robust semi-definite programs by solving polynomial systems},\n  file = {<Go to ISI>://000259435200031:Djvu;DieSch08.pdf:DieSch08.pdf:PDF},\n  endnotereftype = {Journal Article}', 'bibtexAbstract': "In this paper, robust semi-definite programs are considered with the goal of verifying whether a particular LMI relaxation is exact. A procedure is presented showing that verifying exactness amounts to solving a polynomial system. The main contribution of the paper is a new algorithm to compute all isolated solutions of a system of polynomials. Standard techniques in computational algebra, often referred to as Stetter's method [H.J. Stetter, Numerical Polynomial Algebra, SIAM, 2004], involve the computation of a Grobner basis of the ideal generated by the polynomials and further require joint eigenvector computations in order to arrive at the zeros of the polynomial system. Our algorithm does neither require structural knowledge on the polynomial system, nor does it rely on the computation of joint eigenvectors. (c) 2008 Elsevier Inc. All rights reserved.", 'entrytype': 'article', 'author': 'Dietz, S. G. and Scherer, C. W.', 'journal': 'Linear Algebra Appl.', 'number': '7', 'pages': '1758-1778', 'volume': '429', 'year': '2008', 'url': 'https://doi.org/10.1016/j.laa.2008.05.009', 'intrahash': 'ae2ef746bbbf19be1329be45f54f7ca1', 'interhash': '8a981c08100aa8675898413f8d9282c8', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/ae2ef746bbbf19be1329be45f54f7ca1'}, title='{V}erifying exactness of relaxations for robust semi-definite programs by solving polynomial systems', user='simtech', author='Dietz, S. G. and Scherer, C. W.', entrytype='article', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal='Linear Algebra Appl.', preprint_id=None, url='https://doi.org/10.1016/j.laa.2008.05.009', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{R}obust ${L}_2$-gain feedforward control of uncertain systems using dynamic {IQC}s', 'bibtexKey': 'KosSch09a', 'misc': '  shorttitle = {Robust L(2)-gain feedforward control of uncertain systems using dynamic IQCs},\n  file = {<Go to ISI>://000267636600002},\n  issn = {1049-8923},\n  endnotereftype = {Journal Article}', 'bibtexAbstract': 'We consider the problem of robust L(2)-gain disturbance feedforward control for uncertain systems described in the standard LFT form. We use integral quadratic constraints (IQCs) for describing the uncertainty blocks in the system. For technical reasons related to the feedforward problem, throughout the paper, we work with the duals of the constraints involved in robustness analysis using IQCs. We obtain a convex solution to the problem using a state-space characterization of nominal stability that we have developed recently. Specifically, our solution consists of LMI conditions for the existence of a feedforward controller that guarantees a given L(2)-gain for the closed-loop system. We demonstrate the effectiveness of using dynamic IQCs in robust feedforward design through a numerical example. Copyright (C) 2008 John Wiley & Sons, Ltd.', 'entrytype': 'article', 'author': 'Kose, I. E. and Scherer, C. W.', 'journal': 'Int. J. Robust Nonlin.', 'number': '11', 'pages': '1224-1247', 'volume': '19', 'month': 'Jul 25', 'year': '2009', 'url': 'https://doi.org/10.1002/rnc.1374', 'intrahash': '2bace7d849cb7df0a214c4c9400a9d14', 'interhash': '89f278d9dad4c78f153994958230fb15', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/2bace7d849cb7df0a214c4c9400a9d14'}, title='{R}obust ${L}_2$-gain feedforward control of uncertain systems using dynamic {IQC}s', user='simtech', author='Kose, I. E. and Scherer, C. W.', entrytype='article', tag=['EXC310', 'constraints', 'control', 'feedforward', 'from:carsten.scherer', 'imng', 'integral', 'peerReviewed', 'pn4', 'quadratic', 'systems', 'uncertain'], journal='Int. J. Robust Nonlin.', preprint_id=None, url='https://doi.org/10.1002/rnc.1374', doi=None, isbn=None, issn='1049-8923', misc=None),
#  PUMAEntry(bibtex={'title': '{LPV} {C}ontrol for synchronous disturbance attenuation in active magnetic bearings', 'bibtexKey': 'BalKor08', 'misc': '  owner = {mst04}', 'entrytype': 'inproceedings', 'address': 'Ann Arbor, Michigan', 'author': 'Balini, H. M. N. K. and K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', 'booktitle': 'Proc. Dynamic Systems and Control Conf.', 'year': '2008', 'url': 'https://doi.org/10.1115/DSCC2008-2250', 'intrahash': 'b1a820ac6dcc14bff58a6daf924929b0', 'interhash': '22b64c9bf9c6da26e05182d3229e75e2', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/b1a820ac6dcc14bff58a6daf924929b0'}, title='{LPV} {C}ontrol for synchronous disturbance attenuation in active magnetic bearings', user='simtech', author='Balini, H. M. N. K. and K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.1115/DSCC2008-2250', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{R}obust {P}erformance {A}nalysis for {S}tructured {L}inear {T}ime-{V}arying {P}erturbations with {B}ounded {R}ates-of-{V}ariation', 'bibtexKey': 'KorSch07', 'misc': '  shorttitle = {Robust Performance Analysis for Structured Linear Time-Varying Perturbations with Bounded Rates-of-Variation},\n  file = {KorSch07.pdf:KorSch07.pdf:PDF},\n  endnotereftype = {Journal Article}', 'entrytype': 'article', 'author': 'K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', 'journal': 'IEEE T. Automat. Contr.', 'number': '2', 'pages': '197-211', 'volume': '52', 'year': '2007', 'url': 'https://doi.org/10.1109/TAC.2006.890482', 'intrahash': 'f3d7041199c9136ef75f2faa8447374c', 'interhash': '425a6af81ed0a8e6c8b480e2609dc06a', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/f3d7041199c9136ef75f2faa8447374c'}, title='{R}obust {P}erformance {A}nalysis for {S}tructured {L}inear {T}ime-{V}arying {P}erturbations with {B}ounded {R}ates-of-{V}ariation', user='simtech', author='K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', entrytype='article', tag=['EXC310', 'from:carsten.scherer', 'imng', 'iqc', 'peerReviewed', 'pn4'], journal='IEEE T. Automat. Contr.', preprint_id=None, url='https://doi.org/10.1109/TAC.2006.890482', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{S}elf-scheduled {LPV} controller synthesis for doubly-fed induction generators', 'bibtexKey': 'NguyenTien2007', 'misc': '  owner = {mst04}', 'entrytype': 'inproceedings', 'address': 'Los Angeles', 'author': 'Nguyen Tien, H. and Scherer, Carsten W. and Scherpen, J. M. A.', 'booktitle': 'Proc. Windpower', 'year': '2007', 'intrahash': 'ddbc21b6cc3413250ec2fe114ffd96bc', 'interhash': '1d3312f148234c15d01eb2468ae9130c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/ddbc21b6cc3413250ec2fe114ffd96bc'}, title='{S}elf-scheduled {LPV} controller synthesis for doubly-fed induction generators', user='simtech', author='Nguyen Tien, H. and Scherer, Carsten W. and Scherpen, J. M. A.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url=None, doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{R}obust performance of self-scheduled {LPV} control of doubly-fed induction generator in wind energy conversion systems', 'bibtexKey': 'NguSch07', 'misc': '  shorttitle = {Robust performance of self-scheduled LPV control of doubly-fed induction generator in wind energy conversion systems},\n  file = {http://www.scopus.com/scopus/inward/record.file?eid=2-s2.0-51049122107&partnerID=40},\n  endnotereftype = {Conference Proceedings}', 'entrytype': 'inproceedings', 'author': 'Nguyen Tien, H. and Scherer, C. W. and Scherpen, J. M. A.', 'booktitle': 'Eur. Conf. on Power Electronics and Applications', 'year': '2007', 'url': 'https://doi.org/10.1109/EPE.2007.4417460', 'intrahash': 'f1952a9ebd4eb31229f72028977bebec', 'interhash': '62e3fdc3c93fc32669c121cdd97d474e', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/f1952a9ebd4eb31229f72028977bebec'}, title='{R}obust performance of self-scheduled {LPV} control of doubly-fed induction generator in wind energy conversion systems', user='simtech', author='Nguyen Tien, H. and Scherer, C. W. and Scherpen, J. M. A.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.1109/EPE.2007.4417460', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{R}obust controller synthesis for disturbance filter uncertainty described by dynamic integral quadratic constraints', 'bibtexKey': 'DieKor08', 'misc': '  owner = {mst04}', 'entrytype': 'inproceedings', 'address': 'Seoul, South Korea', 'author': 'Dietz, S. G. and K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', 'booktitle': '17th IFAC World Congress', 'pages': '1325 - 1330', 'year': '2008', 'url': 'https://doi.org/10.3182/20080706-5-KR-1001.00227', 'intrahash': '7c58b6a6e202025d6213fb099172eef9', 'interhash': '0f9c2e3165ae1ca2b6f1c40ec639cc9a', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/7c58b6a6e202025d6213fb099172eef9'}, title='{R}obust controller synthesis for disturbance filter uncertainty described by dynamic integral quadratic constraints', user='simtech', author='Dietz, S. G. and K\\"{o}ro\\u{g}lu, H. and Scherer, C. W.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.3182/20080706-5-KR-1001.00227', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{IQC}-based robust stability analysis for {LPV} control of doubly-fed induction generators', 'bibtexKey': 'NguSchSch08', 'misc': '  owner = {mst04}', 'entrytype': 'inproceedings', 'address': 'Hanoi, Vietnam', 'author': 'Nguyen Tien, H. and Scherer, Carsten W. and Scherpen, J. M. A.', 'booktitle': '10th int. Conf. Control, Automation, Robotics and Vision', 'year': '2008', 'url': 'https://doi.org/10.1109/ICARCV.2008.4795804', 'intrahash': 'a2d222d1b2c02efe9b5dc346db765bd1', 'interhash': '4fa9712d8b938cccf018b5d8cb61d3b9', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/a2d222d1b2c02efe9b5dc346db765bd1'}, title='{IQC}-based robust stability analysis for {LPV} control of doubly-fed induction generators', user='simtech', author='Nguyen Tien, H. and Scherer, Carsten W. and Scherpen, J. M. A.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.1109/ICARCV.2008.4795804', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': '{R}obust {M}inimax {S}trategies for {M}issile {G}uidance {D}esign', 'bibtexKey': 'TroSch08', 'misc': '  owner = {mst04}', 'entrytype': 'inproceedings', 'author': 'Trottermant, E. J. and Scherer, C. W. and Weiss, M. and Vermeulen, A. F.', 'booktitle': 'Proc. AIAA Guidance, Navigation and Control Conf.', 'year': '2008', 'url': 'https://doi.org/10.2514/6.2008-6493', 'intrahash': '5473eea2ea4d9523c79ad2dbeae9a8b6', 'interhash': '8e4bc3fd2002feb3effb89fd872484a8', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/5473eea2ea4d9523c79ad2dbeae9a8b6'}, title='{R}obust {M}inimax {S}trategies for {M}issile {G}uidance {D}esign', user='simtech', author='Trottermant, E. J. and Scherer, C. W. and Weiss, M. and Vermeulen, A. F.', entrytype='inproceedings', tag=['EXC310', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://doi.org/10.2514/6.2008-6493', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Integral Quadratic Constraints on Linear Infinite-dimensional Systems for Robust Stability Analysis', 'bibtexKey': 'barreau2020integral', 'entrytype': 'inproceedings', 'author': 'Barreau, M. and Scherer, C. W. and Gouaisbaut, F. and Seuret, A.', 'booktitle': '{IFAC}-{P}apers{O}nline', 'number': '2', 'pages': '7752-7757', 'volume': '53', 'year': '2020', 'url': 'https://www.sciencedirect.com/science/article/pii/S2405896320321297', 'intrahash': '190d8e0992e0c8ca8daa21634a85a65d', 'interhash': '3c78938f36bed830bb4584cf6e83aae4', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/190d8e0992e0c8ca8daa21634a85a65d'}, title='Integral Quadratic Constraints on Linear Infinite-dimensional Systems for Robust Stability Analysis', user='simtech', author='Barreau, M. and Scherer, C. W. and Gouaisbaut, F. and Seuret, A.', entrytype='inproceedings', tag=['EXC2075', 'from:carsten.scherer', 'imng', 'peerReviewed', 'pn4'], journal=None, preprint_id=None, url='https://www.sciencedirect.com/science/article/pii/S2405896320321297', doi=None, isbn=None, issn=None, misc=None),
#  PUMAEntry(bibtex={'title': 'Dissipativity and Integral Quadratic Constraints, Tailored computational robustness tests for complex interconnections', 'bibtexKey': 'Sch22', 'misc': '  eprint = {2105.07401},\n  archiveprefix = {arXiv},\n  primaryclass = {math.OC}', 'entrytype': 'article', 'author': 'Scherer, Carsten', 'journal': 'IEEE Control Systems Magazine (to appear)', 'year': '2022', 'url': 'https://arxiv.org/abs/2105.07401', 'intrahash': '576fe877c1b24c628bdb7c4501950f7e', 'interhash': '28cbb2cf325d693fb90b3c813383bd3c', 'href': 'https://puma.ub.uni-stuttgart.de/api/users/simtech/posts/576fe877c1b24c628bdb7c4501950f7e'}, title='Dissipativity and Integral Quadratic Constraints, Tailored computational robustness tests for complex interconnections', user='simtech', author='Scherer, Carsten', entrytype='article', tag=['EXC2075', 'from:carsten.scherer', 'imng', 'pn4', 'prePrint'], journal='IEEE Control Systems Magazine (to appear)', preprint_id={'type': 'arxiv', 'id': '2105.07401'}, url='https://arxiv.org/abs/2105.07401', doi=None, isbn=None, issn=None, misc=None),
#  ...]
